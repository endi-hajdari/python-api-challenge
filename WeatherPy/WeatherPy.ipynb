# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
! pip install citipy 

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import datetime
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\anaconda3\2020.07\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\anaconda3\2020.07\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | naron
# Processing Record 2 of Set 1 | panguna
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | yumen
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | mount isa
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | nelson bay
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | klaksvik
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | sinnamary
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | hearst
# Processing Record 24 of Set 1 | kutum
# Processing Record 25 of Set 1 | mecca
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | omboue
# Processing Record 30 of Set 1 | muroto
# Processing Record 31 of Set 1 | lixourion
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 1 | altamira
# Processing Record 35 of Set 1 | polunochnoye
# Processing Record 36 of Set 1 | umm lajj
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | rusne
# Processing Record 45 of Set 1 | machiques
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | berlevag
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 0 of Set 2 | codrington
# Processing Record 1 of Set 2 | umm kaddadah
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | camocim
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | oistins
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | asfi
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | tuatapere
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | jelgava
# Processing Record 14 of Set 2 | talara
# Processing Record 15 of Set 2 | pointe michel
# Processing Record 16 of Set 2 | belmonte
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | umuarama
# Processing Record 21 of Set 2 | floro
# Processing Record 22 of Set 2 | kankakee
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | pilot butte
# Processing Record 25 of Set 2 | maluso
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | werda
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 31 of Set 2 | sawang daen din
# Processing Record 32 of Set 2 | macia
# Processing Record 33 of Set 2 | nishihara
# Processing Record 34 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 2 | shimoda
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | virovitica
# Processing Record 38 of Set 2 | esil
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | shwebo
# Processing Record 41 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | nabire
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | xiaoweizhai
# Processing Record 46 of Set 2 | saravan
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | batemans bay
# Processing Record 49 of Set 2 | albany
# Processing Record 0 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | takoradi
# Processing Record 2 of Set 3 | buchanan
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | ust-kut
# Processing Record 5 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | pulawy
# Processing Record 9 of Set 3 | avera
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | macapa
# Processing Record 12 of Set 3 | viesca
# Processing Record 13 of Set 3 | lavrentiya
# Processing Record 14 of Set 3 | itoman
# Processing Record 15 of Set 3 | matagami
# Processing Record 16 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 3 | spirit river
# Processing Record 18 of Set 3 | zlatoustovsk
# City not found. Skipping...
# Processing Record 19 of Set 3 | zurrieq
# Processing Record 20 of Set 3 | te anau
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | colquiri
# Processing Record 27 of Set 3 | kasongo-lunda
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | swedru
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | henties bay
# Processing Record 35 of Set 3 | rawson
# Processing Record 36 of Set 3 | pizhanka
# Processing Record 37 of Set 3 | cabo san lucas
# Processing Record 38 of Set 3 | hirara
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 3 | comodoro rivadavia
# Processing Record 43 of Set 3 | kavaratti
# Processing Record 44 of Set 3 | road town
# Processing Record 45 of Set 3 | paamiut
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | belize
# Processing Record 48 of Set 3 | barra do garcas
# Processing Record 49 of Set 3 | ao luk
# City not found. Skipping...
# Processing Record 0 of Set 4 | haukipudas
# Processing Record 1 of Set 4 | richards bay
# Processing Record 2 of Set 4 | nantucket
# Processing Record 3 of Set 4 | panaba
# Processing Record 4 of Set 4 | kununurra
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | port-cartier
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | vaini
# Processing Record 10 of Set 4 | adrar
# Processing Record 11 of Set 4 | santa rosa
# Processing Record 12 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | okha
# Processing Record 15 of Set 4 | casablanca
# Processing Record 16 of Set 4 | kahului
# Processing Record 17 of Set 4 | tucumcari
# Processing Record 18 of Set 4 | aller
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | katakwi
# Processing Record 22 of Set 4 | jalu
# Processing Record 23 of Set 4 | kishi
# Processing Record 24 of Set 4 | cabedelo
# Processing Record 25 of Set 4 | bubaque
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | sambo creek
# Processing Record 28 of Set 4 | mayo
# Processing Record 29 of Set 4 | lompoc
# Processing Record 30 of Set 4 | puerto escondido
# Processing Record 31 of Set 4 | fortuna
# Processing Record 32 of Set 4 | airai
# Processing Record 33 of Set 4 | vryburg
# Processing Record 34 of Set 4 | egvekinot
# Processing Record 35 of Set 4 | abu kamal
# Processing Record 36 of Set 4 | freetown
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | naberera
# Processing Record 40 of Set 4 | maarianhamina
# Processing Record 41 of Set 4 | ambikapur
# Processing Record 42 of Set 4 | sunndalsora
# Processing Record 43 of Set 4 | lanxi
# Processing Record 44 of Set 4 | georgetown
# Processing Record 45 of Set 4 | buique
# Processing Record 46 of Set 4 | talaya
# Processing Record 47 of Set 4 | ahuimanu
# Processing Record 48 of Set 4 | camacha
# Processing Record 49 of Set 4 | chuy
# Processing Record 0 of Set 5 | abu samrah
# Processing Record 1 of Set 5 | marawi
# Processing Record 2 of Set 5 | saint anthony
# Processing Record 3 of Set 5 | dingle
# Processing Record 4 of Set 5 | kargasok
# Processing Record 5 of Set 5 | walvis bay
# Processing Record 6 of Set 5 | islamkot
# Processing Record 7 of Set 5 | christchurch
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | zhangjiakou
# Processing Record 11 of Set 5 | balkanabat
# Processing Record 12 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 5 | inyonga
# Processing Record 14 of Set 5 | polson
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | katherine
# Processing Record 17 of Set 5 | aksarayskiy
# Processing Record 18 of Set 5 | mahalapye
# Processing Record 19 of Set 5 | jian
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | alofi
# Processing Record 22 of Set 5 | porto-vecchio
# Processing Record 23 of Set 5 | srednekolymsk
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | mirnyy
# Processing Record 27 of Set 5 | bambous virieux
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | krasnoturansk
# Processing Record 30 of Set 5 | aranos
# Processing Record 31 of Set 5 | college place
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | lianzhou
# Processing Record 34 of Set 5 | shiyan
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | sola
# Processing Record 37 of Set 5 | evanston
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | ponta delgada
# Processing Record 40 of Set 5 | wichian buri
# Processing Record 41 of Set 5 | glendive
# Processing Record 42 of Set 5 | talcahuano
# Processing Record 43 of Set 5 | merauke
# Processing Record 44 of Set 5 | makakilo city
# Processing Record 45 of Set 5 | necochea
# Processing Record 46 of Set 5 | gwanda
# Processing Record 47 of Set 5 | anadyr
# Processing Record 48 of Set 5 | ye
# City not found. Skipping...
# Processing Record 49 of Set 5 | port-gentil
# Processing Record 0 of Set 6 | puerto carreno
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | biak
# Processing Record 3 of Set 6 | saint-augustin
# Processing Record 4 of Set 6 | korgen
# Processing Record 5 of Set 6 | kulhudhuffushi
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | vytegra
# Processing Record 8 of Set 6 | oussouye
# Processing Record 9 of Set 6 | kharhial
# Processing Record 10 of Set 6 | sarh
# Processing Record 11 of Set 6 | haines junction
# Processing Record 12 of Set 6 | vestmannaeyjar
# Processing Record 13 of Set 6 | kenora
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | nago
# Processing Record 16 of Set 6 | lower hutt
# Processing Record 17 of Set 6 | lima
# Processing Record 18 of Set 6 | serenje
# Processing Record 19 of Set 6 | yulara
# Processing Record 20 of Set 6 | conway
# Processing Record 21 of Set 6 | bairiki
# Processing Record 22 of Set 6 | gobabis
# Processing Record 23 of Set 6 | qaanaaq
# Processing Record 24 of Set 6 | torbay
# Processing Record 25 of Set 6 | wewak
# Processing Record 26 of Set 6 | karachev
# Processing Record 27 of Set 6 | lao cai
# Processing Record 28 of Set 6 | anderson
# Processing Record 29 of Set 6 | silver city
# Processing Record 30 of Set 6 | usak
# Processing Record 31 of Set 6 | rovaniemi
# Processing Record 32 of Set 6 | jensen beach
# Processing Record 33 of Set 6 | labuhan
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | chapais
# Processing Record 36 of Set 6 | yarensk
# Processing Record 37 of Set 6 | erenhot
# Processing Record 38 of Set 6 | emerald
# Processing Record 39 of Set 6 | dong hoi
# Processing Record 40 of Set 6 | bure
# Processing Record 41 of Set 6 | araguacu
# Processing Record 42 of Set 6 | santiago del estero
# Processing Record 43 of Set 6 | latung
# Processing Record 44 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 6 | monywa
# Processing Record 46 of Set 6 | zhigansk
# Processing Record 47 of Set 6 | takhli
# Processing Record 48 of Set 6 | quba
# Processing Record 49 of Set 6 | jeremoabo
# Processing Record 0 of Set 7 | tilichiki
# Processing Record 1 of Set 7 | trairi
# Processing Record 2 of Set 7 | yeppoon
# Processing Record 3 of Set 7 | iglesias
# Processing Record 4 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 5 of Set 7 | marsaxlokk
# Processing Record 6 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 7 | mixquiahuala
# Processing Record 8 of Set 7 | skibbereen
# Processing Record 9 of Set 7 | pundaguitan
# Processing Record 10 of Set 7 | fuxin
# Processing Record 11 of Set 7 | luwingu
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | riviere-au-renard
# Processing Record 14 of Set 7 | san cristobal
# Processing Record 15 of Set 7 | chimbote
# Processing Record 16 of Set 7 | anshun
# Processing Record 17 of Set 7 | crotone
# Processing Record 18 of Set 7 | wuwei
# Processing Record 19 of Set 7 | bantou
# Processing Record 20 of Set 7 | sarkikaraagac
# Processing Record 21 of Set 7 | khuzdar
# Processing Record 22 of Set 7 | iquique
# Processing Record 23 of Set 7 | leczna
# Processing Record 24 of Set 7 | marystown
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | dalbandin
# Processing Record 27 of Set 7 | iqaluit
# Processing Record 28 of Set 7 | aswan
# Processing Record 29 of Set 7 | ambilobe
# Processing Record 30 of Set 7 | teguldet
# Processing Record 31 of Set 7 | wanning
# Processing Record 32 of Set 7 | lahat
# Processing Record 33 of Set 7 | tailai
# Processing Record 34 of Set 7 | hasaki
# Processing Record 35 of Set 7 | petauke
# Processing Record 36 of Set 7 | nichinan
# Processing Record 37 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 7 | hambantota
# Processing Record 39 of Set 7 | uinskoye
# Processing Record 40 of Set 7 | kalachinsk
# Processing Record 41 of Set 7 | evansville
# Processing Record 42 of Set 7 | barpali
# Processing Record 43 of Set 7 | nuuk
# Processing Record 44 of Set 7 | arrifes
# Processing Record 45 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 7 | dmytrivka
# Processing Record 47 of Set 7 | mount gambier
# Processing Record 48 of Set 7 | tucupita
# Processing Record 49 of Set 7 | airdrie
# Processing Record 0 of Set 8 | janakpur
# Processing Record 1 of Set 8 | sisimiut
# Processing Record 2 of Set 8 | vila velha
# Processing Record 3 of Set 8 | kuytun
# Processing Record 4 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 5 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 8 | cabra
# Processing Record 7 of Set 8 | marsa matruh
# Processing Record 8 of Set 8 | carire
# Processing Record 9 of Set 8 | aras
# Processing Record 10 of Set 8 | mitsamiouli
# Processing Record 11 of Set 8 | khuzhir
# Processing Record 12 of Set 8 | raudeberg
# Processing Record 13 of Set 8 | bielsk podlaski
# Processing Record 14 of Set 8 | aykhal
# Processing Record 15 of Set 8 | abdanan
# Processing Record 16 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | kangaatsiaq
# Processing Record 19 of Set 8 | labuan
# Processing Record 20 of Set 8 | bathsheba
# Processing Record 21 of Set 8 | gus-zheleznyy
# Processing Record 22 of Set 8 | nosy varika
# Processing Record 23 of Set 8 | aripuana
# Processing Record 24 of Set 8 | albox
# Processing Record 25 of Set 8 | moron de la frontera
# Processing Record 26 of Set 8 | emba
# Processing Record 27 of Set 8 | killybegs
# Processing Record 28 of Set 8 | mayna
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | severo-kurilsk
# Processing Record 31 of Set 8 | quelimane
# Processing Record 32 of Set 8 | bonavista
# Processing Record 33 of Set 8 | hithadhoo
# Processing Record 34 of Set 8 | tocopilla
# Processing Record 35 of Set 8 | saldanha
# Processing Record 36 of Set 8 | fasa
# Processing Record 37 of Set 8 | dodge city
# Processing Record 38 of Set 8 | beringovskiy
# Processing Record 39 of Set 8 | puntarenas
# Processing Record 40 of Set 8 | tazovskiy
# Processing Record 41 of Set 8 | apricena
# Processing Record 42 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 8 | chicama
# Processing Record 44 of Set 8 | aberfoyle
# Processing Record 45 of Set 8 | kamaishi
# Processing Record 46 of Set 8 | zheleznodorozhnyy
# Processing Record 47 of Set 8 | sampit
# Processing Record 48 of Set 8 | ayan
# Processing Record 49 of Set 8 | sao gabriel da cachoeira
# Processing Record 0 of Set 9 | aklavik
# Processing Record 1 of Set 9 | salalah
# Processing Record 2 of Set 9 | bud
# Processing Record 3 of Set 9 | bandundu
# Processing Record 4 of Set 9 | los alamos
# Processing Record 5 of Set 9 | namatanai
# Processing Record 6 of Set 9 | seia
# Processing Record 7 of Set 9 | skegness
# Processing Record 8 of Set 9 | san quintin
# Processing Record 9 of Set 9 | tabou
# Processing Record 10 of Set 9 | sawai madhopur
# Processing Record 11 of Set 9 | salmo
# Processing Record 12 of Set 9 | marienburg
# Processing Record 13 of Set 9 | monterey
# Processing Record 14 of Set 9 | sabang
# Processing Record 15 of Set 9 | kristianstad
# Processing Record 16 of Set 9 | sherbakul
# Processing Record 17 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 9 | bereda
# Processing Record 19 of Set 9 | sawtell
# Processing Record 20 of Set 9 | cozumel
# Processing Record 21 of Set 9 | gari
# Processing Record 22 of Set 9 | trinidad
# Processing Record 23 of Set 9 | palmer
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 9 | arman
# Processing Record 27 of Set 9 | haljala
# Processing Record 28 of Set 9 | ewa beach
# Processing Record 29 of Set 9 | baykit
# Processing Record 30 of Set 9 | bodmin
# Processing Record 31 of Set 9 | bermeo
# Processing Record 32 of Set 9 | yerofey pavlovich
# Processing Record 33 of Set 9 | kiunga
# Processing Record 34 of Set 9 | stende
# Processing Record 35 of Set 9 | mandiana
# Processing Record 36 of Set 9 | kaeo
# Processing Record 37 of Set 9 | progreso
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | dalmau
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | faya
# Processing Record 42 of Set 9 | susuman
# Processing Record 43 of Set 9 | half moon bay
# Processing Record 44 of Set 9 | sergeyevka
# Processing Record 45 of Set 9 | zharkent
# Processing Record 46 of Set 9 | rio branco
# Processing Record 47 of Set 9 | urumqi
# Processing Record 48 of Set 9 | hervey bay
# Processing Record 49 of Set 9 | kundla
# Processing Record 0 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 1 of Set 10 | ixtapa
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | atocha
# Processing Record 4 of Set 10 | taylor
# Processing Record 5 of Set 10 | betanzos
# Processing Record 6 of Set 10 | goderich
# Processing Record 7 of Set 10 | pacific grove
# Processing Record 8 of Set 10 | visavadar
# Processing Record 9 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 10 | bonthe
# Processing Record 11 of Set 10 | port washington
# Processing Record 12 of Set 10 | casian
# Processing Record 13 of Set 10 | sechura
# Processing Record 14 of Set 10 | les escoumins
# Processing Record 15 of Set 10 | nouadhibou
# Processing Record 16 of Set 10 | feijo
# Processing Record 17 of Set 10 | tukrah
# Processing Record 18 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 19 of Set 10 | duverge
# Processing Record 20 of Set 10 | epernay
# Processing Record 21 of Set 10 | x-can
# City not found. Skipping...
# Processing Record 22 of Set 10 | porto belo
# Processing Record 23 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 10 | miguel hidalgo
# Processing Record 25 of Set 10 | changji
# Processing Record 26 of Set 10 | mentougou
# Processing Record 27 of Set 10 | sao fidelis
# Processing Record 28 of Set 10 | wanaka
# Processing Record 29 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 10 | upata
# Processing Record 31 of Set 10 | berdigestyakh
# Processing Record 32 of Set 10 | sorkjosen
# Processing Record 33 of Set 10 | karasjok
# Processing Record 34 of Set 10 | clyde river
# Processing Record 35 of Set 10 | burica
# City not found. Skipping...
# Processing Record 36 of Set 10 | berbera
# Processing Record 37 of Set 10 | san patricio
# Processing Record 38 of Set 10 | preobrazheniye
# Processing Record 39 of Set 10 | istok
# Processing Record 40 of Set 10 | porto nacional
# Processing Record 41 of Set 10 | lengshuitan
# Processing Record 42 of Set 10 | sobolevo
# Processing Record 43 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 10 | bogale
# Processing Record 45 of Set 10 | front royal
# Processing Record 46 of Set 10 | ustyuzhna
# Processing Record 47 of Set 10 | puerto madryn
# Processing Record 48 of Set 10 | tarija
# Processing Record 49 of Set 10 | mogadishu
# Processing Record 0 of Set 11 | mlalo
# Processing Record 1 of Set 11 | vardo
# Processing Record 2 of Set 11 | kaka
# Processing Record 3 of Set 11 | madang
# Processing Record 4 of Set 11 | bay roberts
# Processing Record 5 of Set 11 | livramento
# Processing Record 6 of Set 11 | thinadhoo
# Processing Record 7 of Set 11 | wencheng
# Processing Record 8 of Set 11 | bani walid
# Processing Record 9 of Set 11 | lagoa
# Processing Record 10 of Set 11 | auki
# Processing Record 11 of Set 11 | ahipara
# Processing Record 12 of Set 11 | portel
# Processing Record 13 of Set 11 | tual
# Processing Record 14 of Set 11 | khromtau
# Processing Record 15 of Set 11 | marzuq
# Processing Record 16 of Set 11 | tiarei
# Processing Record 17 of Set 11 | colares
# Processing Record 18 of Set 11 | anchorage
# Processing Record 19 of Set 11 | marabba
# Processing Record 20 of Set 11 | bosaso
# Processing Record 21 of Set 11 | tynda
# Processing Record 22 of Set 11 | isla mujeres
# Processing Record 23 of Set 11 | kashi
# Processing Record 24 of Set 11 | ukiah
# Processing Record 25 of Set 11 | socorro
# Processing Record 26 of Set 11 | pades
# Processing Record 27 of Set 11 | dumai
# Processing Record 28 of Set 11 | sainte-rose
# Processing Record 29 of Set 11 | tautira
# Processing Record 30 of Set 11 | macae
# Processing Record 31 of Set 11 | leirvik
# Processing Record 32 of Set 11 | marfino
# Processing Record 33 of Set 11 | port lincoln
# Processing Record 34 of Set 11 | taman
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | tandalti
# Processing Record 37 of Set 11 | at-bashi
# Processing Record 38 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 11 | arlit
# Processing Record 40 of Set 11 | periyanayakkanpalaiyam
# Processing Record 41 of Set 11 | tamworth
# Processing Record 42 of Set 11 | mnogovershinnyy
# Processing Record 43 of Set 11 | kropotkin
# Processing Record 44 of Set 11 | caucaia
# Processing Record 45 of Set 11 | winneba
# Processing Record 46 of Set 11 | jutai
# Processing Record 47 of Set 11 | borovskoy
# Processing Record 48 of Set 11 | port shepstone
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 0 of Set 12 | troitskoye
# Processing Record 1 of Set 12 | mariakani
# Processing Record 2 of Set 12 | markova
# Processing Record 3 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 12 | barra
# Processing Record 5 of Set 12 | carroll
# Processing Record 6 of Set 12 | shingu
# Processing Record 7 of Set 12 | muriwai beach
# Processing Record 8 of Set 12 | laguna
# Processing Record 9 of Set 12 | amapa
# Processing Record 10 of Set 12 | leningradskiy
# Processing Record 11 of Set 12 | blagoyevo
# Processing Record 12 of Set 12 | saint-pacome
# City not found. Skipping...
# Processing Record 13 of Set 12 | jhang
# Processing Record 14 of Set 12 | flin flon
# Processing Record 15 of Set 12 | kedrovyy
# Processing Record 16 of Set 12 | mmabatho
# Processing Record 17 of Set 12 | los llanos de aridane
# Processing Record 18 of Set 12 | brus laguna
# Processing Record 19 of Set 12 | zhanakorgan
# Processing Record 20 of Set 12 | otjimbingwe
# Processing Record 21 of Set 12 | bosobolo
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | deputatskiy
# Processing Record 24 of Set 12 | santa flavia
# Processing Record 25 of Set 12 | yarmouth
# Processing Record 26 of Set 12 | yatou
# Processing Record 27 of Set 12 | nefteyugansk
# Processing Record 28 of Set 12 | san jorge
# Processing Record 29 of Set 12 | hofn
# Processing Record 30 of Set 12 | waipawa
# Processing Record 31 of Set 12 | gushikawa
# Processing Record 32 of Set 12 | barreirinhas
# Processing Record 33 of Set 12 | khani
# Processing Record 34 of Set 12 | ahualulco
# Processing Record 35 of Set 12 | westport
# Processing Record 36 of Set 12 | maldonado
# Processing Record 37 of Set 12 | zhangye
# Processing Record 38 of Set 12 | newport
# Processing Record 39 of Set 12 | hobyo
# Processing Record 40 of Set 12 | wamba
# Processing Record 41 of Set 12 | camacupa
# Processing Record 42 of Set 12 | lac du bonnet
# Processing Record 43 of Set 12 | kamenskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the cities weather data into a pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Showing the Record Count
city_data_df.count()
# Out:
# City          548
# Lat           548
# Lng           548
# Max Temp      548
# Humidity      548
# Cloudiness    548
# Wind Speed    548
# Country       548
# Date          548
# dtype: int64

# %%
# Displaying the sample data using the head() function
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           naron  43.5167   -8.1528    289.62        70         100
# 1         panguna  -6.3164  155.4848    293.10        96          90
# 2  ribeira grande  38.5167  -28.7000    288.02        82          40
# 3            hilo  19.7297 -155.0900    295.53        92          75
# 4           yumen  40.2833   97.2000    264.22        81         100
#
#    Wind Speed Country        Date
# 0        2.98      ES  1670423173
# 1        0.79      PG  1670423173
# 2       12.35      PT  1670423174
# 3        2.57      US  1670423174
# 4        2.22      CN  1670423174

# %%
# Exporting the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 naron  43.5167   -8.1528    289.62        70         100
# 1               panguna  -6.3164  155.4848    293.10        96          90
# 2        ribeira grande  38.5167  -28.7000    288.02        82          40
# 3                  hilo  19.7297 -155.0900    295.53        92          75
# 4                 yumen  40.2833   97.2000    264.22        81         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.98      ES  1670423173
# 1              0.79      PG  1670423173
# 2             12.35      PT  1670423174
# 3              2.57      US  1670423174
# 4              2.22      CN  1670423174

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = 'o', color = 'tab:blue', edgecolors='black')

# Adding title to the plot
plt.title("City Max Latitude vs. Temperature" + time.strftime("%x"))

# Adding axes titles to the plot
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Adding gridlines to the plot
plt.grid(True)

# Saving the figure
plt.savefig("output_data/Fig1.png")

# Displaying the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Building the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = 'o', color = 'tab:blue', edgecolors='black')

# Adding title to the plot
plt.title("City Latitude vs. Humidity" + time.strftime("%x"))

# Adding axes titles to the plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Adding gridlines to the plot
plt.grid(True)

# Saving the figure into the "output_data" folder
plt.savefig("output_data/Fig2.png")

# Displaying the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = 'o', color = 'tab:blue', edgecolors='black')

# Adding title to the plot
plt.title("City Latitude vs. Cloudiness" + time.strftime("%x"))

# Adding axes titles to the plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Adding gridlines to the plot
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = 'o', color = 'tab:blue', edgecolors='black')

# Adding title to the plot
plt.title("City Latitude vs. Wind Speed" + time.strftime("%x"))

# Adding axes titles to the plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Adding gridlines to the plot
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Creating a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0,:]

# Displaying the sample data using the head() function
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 naron  43.5167   -8.1528    289.62        70         100
# 2        ribeira grande  38.5167  -28.7000    288.02        82          40
# 3                  hilo  19.7297 -155.0900    295.53        92          75
# 4                 yumen  40.2833   97.2000    264.22        81         100
# 5            chokurdakh  70.6333  147.9167    253.11        99         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.98      ES  1670423173
# 2             12.35      PT  1670423174
# 3              2.57      US  1670423174
# 4              2.22      CN  1670423174
# 5              1.22      RU  1670423174

# %%
# Creating a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0,:]

# Displaying the sample data using the head() function
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             panguna  -6.3164  155.4848    293.10        96          90
# 6           mount isa -20.7333  139.5000    300.02        34           9
# 7        puerto ayora  -0.7393  -90.3518    296.13        91          72
# 8        punta arenas -53.1500  -70.9167    282.21        37          40
# 9             ushuaia -54.8000  -68.3000    280.94        49          75
#
#          Wind Speed Country        Date
# City_ID
# 1              0.79      PG  1670423173
# 6              0.00      AU  1670423175
# 7              2.24      EC  1670423175
# 8              6.69      CL  1670422887
# 9              7.72      AR  1670423175

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Calculating the correlation coefficient for latitude and maximum temperature on Northern Hemisphere
corr = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and maximum temperature is" + " " + str(corr_coeff))

# Linear regression model on Northern Hemisphere
slope, intercept, r, p, se = st.linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
r_values = northern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"],color='tab:blue')
plt.plot(northern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Adding the title on the final plot
plt.title("Max Temperature as a Function of Latitude (Northern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and maximum temperature is -0.86
# The linear regression equation is y=-0.75x+308.99
# r-squared = 0.736

# %%
# Calculating the correlation coefficient for latitude and maximum temperature on Southern Hemisphere
corr = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and maximum temperature is" + " " + str(corr_coeff))

# Linear regression model on Southern Hemisphere
slope, intercept, r, p, se = st.linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
r_values = southern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],color='tab:blue')
plt.plot(southern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Adding the title on the final plot
plt.title("Max Temperature as a Function of Latitude (Southern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and maximum temperature is 0.6
# The linear regression equation is y=0.3x+303.02
# r-squared = 0.366

# %% [markdown]
# **Discussion about the linear relationship:**
# - **Northern Hemisphere:** We see an inversely proportional relationship between maximum temperature and latitude. That is, as we move further north away from the equator, the smaller the maximum temperature value is.
# - **Southern Hemisphere:** We see a directly proportional relationship between maximum temperature and latitude. That is, as we move further towards the equator, the larger the maximum temperature value is.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Calculating the correlation coefficient for latitude and humidity on Northern Hemisphere
corr = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and humidity is " + " " + str(corr_coeff))

# Linear regression model on Northern Hemisphere
slope, intercept, r, p, se = st.linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
r_values = northern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is" + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"],color='tab:blue')
plt.plot(northern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Adding the title on the final plot
plt.title("Humidity as a Function of Latitude (Northern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and humidity is  0.4
# The linear regression equation isy=0.43x+58.6
# r-squared = 0.163

# %%
# Calculating the correlation coefficient for latitude and maximum temperature on Southern Hemisphere
corr = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and humidity is" + " " + str(corr_coeff))

# Linear regression model on Southern Hemisphere
slope, intercept, r, p, se = st.linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
r_values = southern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"],color='tab:blue')
plt.plot(southern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Adding the title on the final plot
plt.title("Humidity as a Function of Latitude (Southern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and humidity is 0.05
# The linear regression equation is y=0.08x+69.05
# r-squared = 0.003

# %% [markdown]
# **Discussion about the linear relationship:**
# - **Nothern Hemisphere:** We see a directly proportional relationship between humidity and latitude. That is, as we move away from the equator in the northern direction, the humidity increases.
# - **Southern Hemisphere:** We see a directly proportional relationship between humidity and latitude, however, less pronounced than we saw in the Northern Hemisphere given the smaller slope. That is, as we move twoards the equator, the humidity also slightly increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Calculating the correlation coefficient for latitude and cloudiness on Northern Hemisphere
corr = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and cloudiness is" + " " + str(corr_coeff))

# Linear regression model on Northern Hemisphere
slope, intercept, r, p, se = st.linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
r_values = northern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"],color='tab:blue')
plt.plot(northern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Adding the title on the final plot
plt.title("Cloudiness as a Function of Latitude (Northern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and cloudiness is 0.33
# The linear regression equation is y=0.68x+34.03
# r-squared = 0.11

# %%
# Calculating the correlation coefficient for latitude and cloudiness on Southern Hemisphere
corr = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and cloudiness is" + " " + str(corr_coeff))

# Linear regression model on Southern Hemisphere
slope, intercept, r, p, se = st.linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
r_values = southern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"],color='tab:blue')
plt.plot(southern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Adding the title on the final plot
plt.title("Cloudiness as a Function of Latitude (Southern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and cloudiness is 0.08
# The linear regression equation is y=0.22x+66.52
# r-squared = 0.007

# %% [markdown]
# **Discussion about the linear relationship:**
# - **Nothern Hemisphere:** We see a directly proportional relationship between cloudiness and latitude. That is, as we move away from the equator in the northern direction, the cloudiness increases.
# - **Southern Hemisphere:** We see a directly proportional relationship between cloudiness and latitude, however, less pronounced than we saw in the Northern Hemisphere given the smaller slope. That is, as we move twoards the equator, the cloudiness also slightly increases.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Calculating the correlation coefficient for latitude and wind speed on Northern Hemisphere
corr = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and wind speed is" + " " + str(corr_coeff))

# Linear regression model on Northern Hemisphere
slope, intercept, r, p, se = st.linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
r_values = northern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"],color='tab:blue')
plt.plot(northern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Adding the title on the final plot
plt.title("Wind Speed as a Function of Latitude (Northern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and wind speed is 0.14
# The linear regression equation is y=0.02x+2.71
# r-squared = 0.019

# %%
# Calculating the correlation coefficient for latitude and wind speed on Southern Hemisphere
corr = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
corr_coeff = round(corr[0],2)
print("The correlation between latitude and wind speed is" + " " + str(corr_coeff))

# Linear regression model on Southern Hemisphere
slope, intercept, r, p, se = st.linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
r_values = southern_hemi_df["Lat"]*slope + intercept
lin_eq = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
print("The linear regression equation is " + str(lin_eq))

# Generating the scatter plot and fitting line of best fit via linear regression
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"],color='tab:blue')
plt.plot(southern_hemi_df["Lat"], r_values, color='tab:red')

# Labelling the x-axis and y-axis of the final plot, respectively
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Adding the title on the final plot
plt.title("Wind Speed as a Function of Latitude (Southern Hemisphere)")

# Displaying the final plot
plt.show()

# Printing the model's r-squared value
print(f"r-squared = {round(r**2,3)}")
# Out:
# The correlation between latitude and wind speed is -0.31
# The linear regression equation is y=-0.06x+3.13
# r-squared = 0.095

# %% [markdown]
# **Discussion about the linear relationship:**
# - **Nothern Hemisphere:** We see a directly proportional relationship between wind speed and latitude. That is, as we move away from the equator in the northern direction, the wind speed also steadily increases.
# - **Southern Hemisphere:** We see an inversely proportional relationship between wind speed and latitude. That is, as we move twoards the equator, the wind speed decreases.
